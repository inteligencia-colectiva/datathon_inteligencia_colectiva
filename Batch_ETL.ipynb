# %% [markdown]
# # EDA
# > ## **Metadata files**
#
# **We download the metadata files that are hosted in an Azure datalake, we will use the spark library to proceed with the download**
#
# Data Stored in Azure Data Lake Storage (ADLS):
# - Storage Account: safactoreddatathon
# - Container: source-files
# - Authentication Method: SAS Token
# - SAS Token:
# sp=rle&st=2023-07-25T18:12:36Z&se=2023-08-13T02:12:36Z&sv=2022-11-02&sr=c&sig=l2TCTwPWN8LSM922lR%2Fw78mZWQK2ErEOQDUaCJosIaw%3D
# - SAS URL:
# https://safactoreddatathon.blob.core.windows.net/source-files?sp=rle&st=2023-07-25T18:12:36Z&se=2023-08-13T02:12:36Z&sv=2022-11-02&sr=c&sig=l2TCTwPWN8LSM922lR%2Fw78mZWQK2ErEOQDUaCJosIaw%3D
# - Objects:
# - source-fies/amazon_metadata

# %%
# Set the SAS token as a configuration property for accessing Azure Blob Storage container.
spark.conf.set(f"fs.azure.sas.source-files.safactoreddatathon.blob.core.windows.net",'sp=rle&st=2023-07-25T18:12:36Z&se=2023-08-13T02:12:36Z&sv=2022-11-02&sr=c&sig=l2TCTwPWN8LSM922lR%2Fw78mZWQK2ErEOQDUaCJosIaw%3D')

# List the contents of the root directory in the Azure Blob Storage container.
dbutils.fs.ls('wasbs://source-files@safactoreddatathon.blob.core.windows.net')
# Out:
# Out[1]: [FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_metadata/', name='amazon_metadata/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/', name='amazon_reviews/', size=0, modificationTime=0)]

# %% [markdown]
# > ## **Data frame analysis**
#
# **We will take a random file to visualize the type of information that the dataframe contains**

# %%
from pyspark.sql.functions import expr

df2 = spark.read.option("header",True).json('wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_metadata/partition_10')
df2.show(50)
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+
# |            also_buy|           also_view|      asin|               brand|            category|                date|         description|             details|             feature|                 fit|               image|            main_cat|          price|                rank|similar_item|               tech1|tech2|               title|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+
# |                  []|                  []|B0016MJOQM|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|[Great looking 10...|{null, null, null...|[100% Cotton, Mac...|                    |[https://images-n...|<img src="https:/...|         $11.94|24,469,411 in Clo...|            |                    |     |Got Orr Little Bo...|
# |                  []|[B00SFZYXAK, B001...|B0016MJWDW|         RG Costumes|[Clothing, Shoes ...|                    |[Includes: Jumpsu...|{null, null, null...|           [90079-S]|                    |                  []|        Toys & Games|         $27.25|[">#720,785 in To...|            |                    |     |Grey Cute-T Bat K...|
# |                  []|                  []|B0016MJQO2|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|[Great looking 10...|{null, null, null...|[100% Cotton, Mac...|                    |[https://images-n...|<img src="https:/...|$11.44 - $14.77|6,110,607 in Clot...|            |                    |     |Got Orr Men's Tee...|
# |                  []|                  []|B0016MLJ1K|         Switchables|[Clothing, Shoes ...|      March 27, 2008|[That's right! Th...|{null, null, null...|[Stained glass, D...|                    |                  []|Tools & Home Impr...|               |[">#2,134,193 in ...|            | class="a-keyvalu...|     |Switchables Stain...|
# |                  []|                  []|B0016MM1IK|                    |[Clothing, Shoes ...|<div class="a-fix...|[From its humble ...|{null, null, null...|[100% Leather, Sy...|                    |[https://images-n...|<img src="https:/...|               |18,929,031 in Clo...|            |                    |     |CLARKS Women's Ge...|
# |                  []|                  []|B0016MLUNW|                    |[Clothing, Shoes ...|<div class="a-fix...|[The
             BEARPAW|[Clothing, Shoes ...|<div class="a-fix...|[Bearpaw footwear...|{null, null, null...|[100% Suede, Rubb...|                    |[https://images-n...|<img src="https:/...|               |19,274,450 in Clo...|            |                    |     |BEARPAW Jasmine C...|
# |                  []|                  []|B0016N0I0C|             BEARPAW|[Clothing, Shoes ...|<div class="a-fix...|[Bearpaw footwear...|{null, null, null...|[100% Suede, Rubb...|                    |[https://images-n...|<img src="https:/...|               |12,089,809 in Clo...|            |                    |     |BEARPAW Jasmine C...|
# |                  []|                  []|B0016MZXEO|               bo'em|[Clothing, Shoes ...|<div class="a-fix...|[The bo'em collec...|{null, null, null...|[100% Leather, Le...|                    |[https://images-n...|<img src="https:/...|               |24,978,452 in Clo...|            |                    |     |bo'em Women's Ula...|
# |                  []|                  []|B0016N0SP2|                    |[Clothing, Shoes ...|<div class="a-fix...|[RAMPAGE caters t...|{null, null, null...|[100% Synthetic, ...|                    |[https://images-n...|<img src="https:/...|               |23,668,894 in Clo...|            |                    |     |Rampage Women's C...|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+
# only showing top 50 rows

# %% [markdown]
# **We will make a small view of the structure of how each column of the dataframe is formed**

# %%
df.printSchema()
# Out:
# root
#  |-- also_buy: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- also_view: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- asin: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- date: string (nullable = true)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- details: struct (nullable = true)
#  |    |-- \n    Item Weight: \n    : string (nullable = true)
#  |    |-- \n    Product Dimensions: \n    : string (nullable = true)
#  |    |-- ASIN:: string (nullable = true)
#  |    |-- ASIN: : string (nullable = true)
#  |    |-- Batteries: string (nullable = true)
#  |    |-- Discontinued by manufacturer:: string (nullable = true)
#  |    |-- Domestic Shipping: : string (nullable = true)
#  |    |-- International Shipping: : string (nullable = true)
#  |    |-- Item model number:: string (nullable = true)
#  |    |-- Shipping Weight:: string (nullable = true)
#  |    |-- UPC:: string (nullable = true)
#  |-- feature: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fit: string (nullable = true)
#  |-- image: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- main_cat: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- similar_item: string (nullable = true)
#  |-- tech1: string (nullable = true)
#  |-- tech2: string (nullable = true)
#  |-- title: string (nullable = true)

# %% [markdown]
# **We extract the information that is inside the dictionaries that are von the values of the 'details' column, and with this we will create new columns, we will extract Item Weight, Product Dimensions, Domestic Shipping, International Shipping, Item model number, Shipping Weight. Then we will remove the 'details' column**

# %%
from pyspark.sql.functions import first

primer_elemento = df2.select(first("details")).collect()[0][0]
print(primer_elemento)
# Out:
# Row(
#     Item Weight:
#     =None,
#     Product Dimensions:
#     =None, ASIN:=None, ASIN: =None, Batteries=None, Discontinued by manufacturer:=None, Domestic Shipping: =None, International Shipping: =None, Item model number:=None, Shipping Weight:=None, UPC:=None)

# %%
# Funtion return key
def get_value(details, key):
    try:
        return details[key]
    except:
        return None

try:
    df2 = df2.withColumn("item_weight", get_value(df2.details, "_____Item Weight:____"))
except:
    pass

try:
    df2 = df2.withColumn("product_dimensions", get_value(df2.details, "\n    Product Dimensions: \n    "))
except:
    pass

try:
    df2 = df2.withColumn("domestic_shipping", get_value(df2.details, "Domestic Shipping: "))
except:
    pass

try:
    df2 = df2.withColumn("international_shipping", get_value(df2.details, "International Shipping: "))
except:
    pass

try:
    df2 = df2.withColumn("item_model_number", get_value(df2.details, "Item model number:"))
except:
    pass

try:
    df2 = df2.withColumn("shipping_weight", get_value(df2.details, "Shipping Weight:"))
except:
    pass

try:
    df2 = df2.withColumn("batteries", get_value(df2.details, "Batteries"))
except:
    pass

df2 = df2.drop('details')

# %%
df2.show(50)
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------
|              null|             null|                  null|             null|           null|     null|
# |                  []|                  []|B0016MZENE|                    |[Clothing, Shoes ...|<div class="a-fix...|[What began as a ...|[100% Patent, Syn...|                    |[https://images-n...|<img src="https:/...|               |22,329,129 in Clo...|            |                    |     |Steve Madden Wome...|              null|             null|                  null|             null|           null|     null|
# |                  []|                  []|B0016N0I5M|             BEARPAW|[Clothing, Shoes ...|<div class="a-fix...|[Bearpaw footwear...|[100% Suede, Rubb...|                    |[https://images-n...|<img src="https:/...|               |19,274,450 in Clo...|            |                    |     |BEARPAW Jasmine C...|              null|             null|                  null|             null|           null|     null|
# |                  []|                  []|B0016N0I0C|             BEARPAW|[Clothing, Shoes ...|<div class="a-fix...|[Bearpaw footwear...|[100% Suede, Rubb...|                    |[https://images-n...|<img src="https:/...|               |12,089,809 in Clo...|            |                    |     |BEARPAW Jasmine C...|              null|             null|                  null|             null|           null|     null|
# |                  []|                  []|B0016MZXEO|               bo'em|[Clothing, Shoes ...|<div class="a-fix...|[The bo'em collec...|[100% Leather, Le...|                    |[https://images-n...|<img src="https:/...|               |24,978,452 in Clo...|            |                    |     |bo'em Women's Ula...|              null|             null|                  null|             null|           null|     null|
# |                  []|                  []|B0016N0SP2|                    |[Clothing, Shoes ...|<div class="a-fix...|[RAMPAGE caters t...|[100% Synthetic, ...|                    |[https://images-n...|<img src="https:/...|               |23,668,894 in Clo...|            |                    |     |Rampage Women's C...|              null|             null|                  null|             null|           null|     null|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+------------------+-----------------+----------------------+-----------------+---------------+---------+
# only showing top 50 rows

# %% [markdown]
# **Now let's proceed with the 'feature' column. This column has array values, and that is why we will get a view of the first row.**

# %%
from pyspark.sql.functions import first

primer_elemento = df2.select(first("feature")).collect()[0][0]
print(primer_elemento)
# Out:
# ['100% Cotton', 'Machine wash and dry', "To purchase in big boy's sizes 2T through 7T check our separate Amazon ad for those sizes.", 'Unisex shirt, fits both boys and girls', '<span class="a-text-bold">Shipping Weight:\n                    </span>\n                    <span>1.06 pounds (<a href=\'https://www.amazon.com/gp/help/seller/shipping.html/ref=dp_pd_shipping?_encoding=UTF8&amp;seller=A1R790XMSEUJNL&amp;asin=B00W4C0SVI\'>View shipping rates and policies</a>)</span>', '<span class="a-text-bold">ASIN:\n                    </span>\n                    <span>B00W4C0SVI</span>', '', '<span class="a-text-bold">Date first listed on Amazon:\n                    </span>\n                    <span>April 14, 2015</span>', '<span class="a-text-bold">\n                    Average Customer Review:\n                </span>\n                \n\n\n\n\n<style type="text/css">\n    /* \n    * Fix for UDP-1061. Average customer reviews has a small extra line on hover \n    * https://omni-grok.amazon.com/xref/src/appgroup/websiteTemplates/retail/SoftlinesDetailPageAssets/udp-intl-lock/src/legacy.css?indexName=WebsiteTemplates#40\n    */\n    .noUnderline a:hover { \n        text-decoration: none; \n    }\n</style>\n\n\n\n    \n    \n    \n    \n        \n\n        \n\n        \n        \n        \n        \n\t\t\n\t\t\n\t\t\n\t\t\n\t\t        \n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t        \n        \n\n        <div id="detailBullets_averageCustomerReviews" class="a-spacing-none" data-asin="B00W4C0SVI" data-ref="dpx_acr_pop_" >\n            \n            \n            \n                \n                \n                    \n\n\n\n\n\n\n\n\n\n\n        <span class="a-declarative" data-action="acrStarsLink-click-metrics" data-acrStarsLink-click-metrics="{}">\n            \n\n\n\n\n\n    <span id="acrPopover" class="reviewCountTextLinkedHistogram noUnderline" title="5.0 out of 5 stars">\n        <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;max-width&quot;:&quot;700&quot;,&quot;closeButton&quot;:&quot;false&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/gp/customer-reviews/widgets/average-customer-review/popover/ref=dpx_acr_pop_?contextId=dpx&amp;asin=B00W4C0SVI&quot;}">\n            <a href="javascript:void(0)" class="a-popover-trigger a-declarative">\n                \n\n<i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>\n                \n            <i class="a-icon a-icon-popover"></i></a>\n        </span>\n        <span class="a-letter-space"></span>\n    </span>\n\n\n        </span>\n        <span class="a-letter-space"></span>\n        \n        \n\n        \n\n        \n\n        \n        \n        \n        \n        \n        \n        \n            \n            \n                <span class="a-declarative" data-action="acrLink-click-metrics" data-acrLink-click-metrics="{}">\n                    <a id="acrCustomerReviewLink" class="a-link-normal" href="#customerReviews">\n                        <span id="acrCustomerReviewText" class="a-size-base">1 customer review</span>\n                    </a>\n                </span>\n            \n                <script type="text/javascript">\n                    P.when(\'A\', \'ready\').execute(function(A) {\n                        A.declarative(\'acrLink-click-metrics\', \'click\', { "allowLinkDefault" : true }, function(event){\n                            if(window.ue) {\n                                ue.count("acrLinkClickCount", (ue.count("acrLinkClickCount") || 0) + 1);\n                            }\n                        });\n                    });\n                </script>\n            \n            \n            \n            \n        \n        \n        <script type="text/javascript">\n            P.when(\'A\', \'cf\').execute(function(A) {\n                A.declarative(\'acrStarsLink-click-metrics\', \'click\', { "allowLinkDefault" : true },  function(event ...

# %% [markdown]
# **We notice that some of its values come in HTML structure so we will make a better view by iterating over the array**

# %%
primer_elemento = df2.select(first("feature")).collect()[0][0]
for texto in primer_elemento:
    print(texto)
# Out:
# 100% Cotton
# Machine wash and dry
# To purchase in big boy's sizes 2T through 7T check our separate Amazon ad for those sizes.
# Unisex shirt, fits both boys and girls
# <span class="a-text-bold">Shipping Weight:
#                     </span>
#                     <span>1.06 pounds (<a href='https://www.amazon.com/gp/help/seller/shipping.html/ref=dp_pd_shipping?_encoding=UTF8&amp;seller=A1R790XMSEUJNL&amp;asin=B00W4C0SVI'>View shipping rates and policies</a>)</span>
# <span class="a-text-bold">ASIN:
#                     </span>
#                     <span>B00W4C0SVI</span>
#
# <span class="a-text-bold">Date first listed on Amazon:
#                     </span>
#                     <span>April 14, 2015</span>
# <span class="a-text-bold">
#                     Average Customer Review:
#                 </span>
#
#
#
#
#
# <style type="text/css">
#     /*
#     * Fix for UDP-1061. Average customer reviews has a small extra line on hover
#     * https://omni-grok.amazon.com/xref/src/appgroup/websiteTemplates/retail/SoftlinesDetailPageAssets/udp-intl-lock/src/legacy.css?indexName=WebsiteTemplates#40
#     */
#     .noUnderline a:hover {
#         text-decoration: none;
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <div id="detailBullets_averageCustomerReviews" class="a-spacing-none" data-asin="B00W4C0SVI" data-ref="dpx_acr_pop_" >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <span class="a-declarative" data-action="acrStarsLink-click-metrics" data-acrStarsLink-click-metrics="{}">
#
#
#
#
#
#
#     <span id="acrPopover" class="reviewCountTextLinkedHistogram noUnderline" title="5.0 out of 5 stars">
#         <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;max-width&quot;:&quot;700&quot;,&quot;closeButton&quot;:&quot;false&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/gp/customer-reviews/widgets/average-customer-review/popover/ref=dpx_acr_pop_?contextId=dpx&amp;asin=B00W4C0SVI&quot;}">
#             <a href="javascript:void(0)" class="a-popover-trigger a-declarative">
#
#
# <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i>
#
#             <i class="a-icon a-icon-popover"></i></a>
#         </span>
#         <span class="a-letter-space"></span>
#     </span>
#
#
#         </span>
#         <span class="a-letter-space"></span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <span class="a-declarative" data-action="acrLink-click-metrics" data-acrLink-click-metrics="{}">
#                     <a id="acrCustomerReviewLink" class="a-link-normal" href="#customerReviews">
#                         <span id="acrCustomerReviewText" class="a-size-base">1 customer review</span>
#                     </a>
#                 </span>
#
#                 <script type="text/javascript">
#                     P.when('A', 'ready').execute(function(A) {
#                         A.declarative('acrLink-click-metrics', 'click', { "allowLinkDefault" : true }, function(event){
#                             if(window.ue) {
#                                 ue.count("acrLinkClickCount", (ue.count("acrLinkClickCount") || 0) + 1);
#                             }
#                         });
#                     });
#                 </script>
#
#
#
#
#
#
#         <script type="text/javascript">
#             P.when('A', 'cf').execute(function(A) {
#                 A.declarative('acrStarsLink-click-metrics', 'click', { "allowLinkDefault" : true },  function(event){
#                     if(window.ue) {
#                         ue.count("acrStarsLinkWithPopoverClickCount", (ue.count("acrStarsLinkWithPopoverClickCount") || 0) + 1);
#                     }
#                 });
#             });
#         </script>
#
#
#
#
#         </div>

# %% [markdown]
# **Indeed, some values within the array have an HTML structure and also have line breaks and spaces, for which we will apply an exploit and a join to remove both spaces and line breaks in such a way as not to put some values at risk.**

# %%
primer_elemento = df2.select(first("feature")).collect()[0][0]
for texto in primer_elemento:
    texto = texto.replace("\n", "")
    lista_texto = texto.split()
    texto = " ".join(lista_texto)
    print(texto)
# Out:
# 100% Cotton
# Machine wash and dry
# To purchase in big boy's sizes 2T through 7T check our separate Amazon ad for those sizes.
# Unisex shirt, fits both boys and girls
# <span class="a-text-bold">Shipping Weight: </span> <span>1.06 pounds (<a href='https://www.amazon.com/gp/help/seller/shipping.html/ref=dp_pd_shipping?_encoding=UTF8&amp;seller=A1R790XMSEUJNL&amp;asin=B00W4C0SVI'>View shipping rates and policies</a>)</span>
# <span class="a-text-bold">ASIN: </span> <span>B00W4C0SVI</span>
#
# <span class="a-text-bold">Date first listed on Amazon: </span> <span>April 14, 2015</span>
# <span class="a-text-bold"> Average Customer Review: </span> <style type="text/css"> /* * Fix for UDP-1061. Average customer reviews has a small extra line on hover * https://omni-grok.amazon.com/xref/src/appgroup/websiteTemplates/retail/SoftlinesDetailPageAssets/udp-intl-lock/src/legacy.css?indexName=WebsiteTemplates#40 */ .noUnderline a:hover { text-decoration: none; }</style> <div id="detailBullets_averageCustomerReviews" class="a-spacing-none" data-asin="B00W4C0SVI" data-ref="dpx_acr_pop_" > <span class="a-declarative" data-action="acrStarsLink-click-metrics" data-acrStarsLink-click-metrics="{}"> <span id="acrPopover" class="reviewCountTextLinkedHistogram noUnderline" title="5.0 out of 5 stars"> <span class="a-declarative" data-action="a-popover" data-a-popover="{&quot;max-width&quot;:&quot;700&quot;,&quot;closeButton&quot;:&quot;false&quot;,&quot;position&quot;:&quot;triggerBottom&quot;,&quot;url&quot;:&quot;/gp/customer-reviews/widgets/average-customer-review/popover/ref=dpx_acr_pop_?contextId=dpx&amp;asin=B00W4C0SVI&quot;}"> <a href="javascript:void(0)" class="a-popover-trigger a-declarative"> <i class="a-icon a-icon-star a-star-5"><span class="a-icon-alt">5.0 out of 5 stars</span></i> <i class="a-icon a-icon-popover"></i></a> </span> <span class="a-letter-space"></span> </span> </span> <span class="a-letter-space"></span> <span class="a-declarative" data-action="acrLink-click-metrics" data-acrLink-click-metrics="{}"> <a id="acrCustomerReviewLink" class="a-link-normal" href="#customerReviews"> <span id="acrCustomerReviewText" class="a-size-base">1 customer review</span> </a> </span> <script type="text/javascript"> P.when('A', 'ready').execute(function(A) { A.declarative('acrLink-click-metrics', 'click', { "allowLinkDefault" : true }, function(event){ if(window.ue) { ue.count("acrLinkClickCount", (ue.count("acrLinkClickCount") || 0) + 1); } }); }); </script> <script type="text/javascript"> P.when('A', 'cf').execute(function(A) { A.declarative('acrStarsLink-click-metrics', 'click', { "allowLinkDefault" : true }, function(event){ if(window.ue) { ue.count("acrStarsLinkWithPopoverClickCount", (ue.count("acrStarsLinkWithPopoverClickCount") || 0) + 1); } }); }); </script> </div>

# %% [markdown]
# **We proceed to extract the information and save it in new columns, such as Date first listed on Amazon, Package Dimensions, Shipping Weight, Domestic Shipping, International Shipping, and we will create a new column to extract those data that do not have the HTML structure which will be the new one feature**

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import ArrayType, StringType, MapType, StructType, StructField
import re

def extraer_valores(lista):
    valores = {
        "fecha": None,
        "package_dimensions": None,
        "shipping_weight": None,
        "domestic_shipping": None,
        "international_shipping": None
    }
    nueva_lista = []
    
    for elemento in lista:
        elemento = elemento.replace("\n", "")
        lista_texto = elemento.split()
        elemento = " ".join(lista_texto)

        match = re.search(r"Date first listed on Amazon: </span> <span>([^<]+)", elemento)
        if match:
            valores["date"] = match.group(1)
        
        match = re.search(r"Package Dimensions: </span> <span>([^<]+)", elemento)
        if match:
            valores["package_dimensions"] = match.group(1)
        
        match = re.search(r"Shipping Weight: </span> <span>([^<]+)", elemento)
        if match:
            valores["shipping_weight_2"] = match.group(1)
        
        match = re.search(r"Domestic Shipping: </span> <span>([^<]+)", elemento)
        if match:
            valores["domestic_shipping_2"] = match.group(1)
        
        match = re.search(r"International Shipping: </span> <span>([^<]+)", elemento)
        if match:
            valores["international_shipping_2"] = match.group(1)
    
        if not re.search(r"span class", elemento):
            nueva_lista.append(elemento)

    return (valores, nueva_lista)

# %%
from pyspark.sql.functions import first

primer_elemento = df2.select(first("feature")).collect()[0][0]

extraer_valores(primer_elemento)
# Out:
# Out[23]: ({'fecha': None,
#   'package_dimensions': None,
#   'shipping_weight': None,
#   'domestic_shipping': None,
#   'international_shipping': None,
#   'shipping_weight_2': '1.06 pounds (',
#   'date': 'April 14, 2015'},
#  ['100% Cotton',
#   'Machine wash and dry',
#   "To purchase in big boy's sizes 2T through 7T check our separate Amazon ad for those sizes.",
#   'Unisex shirt, fits both boys and girls',
#   ''])

# %%
# Defines the output schema of the UDF
schema = StructType([
        StructField("value_temp", MapType(StringType(), StringType())),
        StructField("new_feature", ArrayType(StringType()))
    ])

# Create the udf extraer_valores_udf 
extraer_valores_udf = udf(extraer_valores, schema)

# Applies the UDF to the desired column and stores the results in two new columns
df2 = df2.withColumn("resultado", extraer_valores_udf("feature"))
df2 = df2.select("*", "resultado.value_temp", "resultado.new_feature")

# We create new columns with the values and keys of the value_temp column
df2 = df2.withColumn("domestic_shipping_2", col('value_temp').getItem('domestic_shipping')) \
        .withColumn("product_dimensions", col("value_temp").getItem("package_dimensions")) \
        .withColumn("new_date", col('value_temp').getItem('date')) \
        .withColumn("shipping_weight_2", col("value_temp").getItem("shipping_weight").cast("string")) \
        .withColumn("domestic_shipping_2", col('value_temp').getItem('domestic_shipping').cast("string")) \
        .withColumn("international_shipping_2", col("value_temp").getItem("international_shipping").cast("string")) \
            
df2 = df2.drop('details', 'resultado', 'value_temp', 'feature')

# %%
df2.show(50)
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+
# |            also_buy|           also_view|      asin|               brand|            category|                date|         description|                 fit|               image|            main_cat|          price|                rank|similar_item|               tech1|tech2|               title|  product_dimensions|domestic_shipping|international_shipping|item_model_number|shipping_weight|batteries|         new_feature|domestic_shipping_2|          new_date|shipping_weight_2|international_shipping_2|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+
# |                  []|                  []|B0016MJOQM|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|[Great looking 10...|                    |[https://images-n...|<img src="https:/...|         $11.94|24,469,411 in Clo...|            |                    |     |Got Orr Little Bo...|                null|             null|                  null|             null|           null|     null|[100% Cotton, Mac...|               null|    April 14, 2015|             null|                    null|
# |                  []|[B00SFZYXAK, B001...|B0016MJWDW|         RG Costumes|[Clothing, Shoes ...|                    |[Includes: Jumpsu...|                    |                  []|        Toys & Games|         $27.25|[">#720,785 in To...|            |                    |     |Grey Cute-T Bat K...|                null|             null|                  null|             null|           null|     null|           [90079-S]|               null|              null|             null|                    null|
# |                  []|                  []|B0016MJQO2|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|[Great looking 10...|                    |[https://images-n...|<img src="https:/...|$11.44 - $14.77|6,110,607 in Clot...|            |                    |     |Got Orr Men's Tee...|                null|             null|                  null|             null|           null|     null|[100% Cotton, Mac...|               null|    March 27, 2008|             null|                    null|
# |                  []|                  []|B0016MLJ1K|         Switchables|[Clothing, Shoes ...|      March 27, 2008|[That's right! Th...|                    |                  []|Tools & Home Impr...|               |[">#2,134,193 in ...|            | class="a-keyvalu...|     |Switchables Stain...|                null|             null|                  null|             null|           null|     null|[Stained glass, D...|               null|              null|             null|                    null|
# |                  []|                  []|B0016MM1IK|                    |[Clothing, Shoes ...|<div class="a-fix...|[From its humble ...|                    |[https://images-n...|<img src="https:/...|               |18,929,031 in Clo...|            |                    |     |CLARKS Women's Ge...|12.1 x 7.3 x 4.2 ...|             null|                  null|             null|           null|     null|[100% Leather, Sy...|               null| September 4, 2009|             null|                    null|
# |                  []|                  []|B0016MLUNW|                    |[Clothing, Shoes ...|<div class="a-fix...|[The
               bo'em|[Clothing, Shoes ...|<div class="a-fix...|[The bo'em collec...|                    |[https://images-n...|<img src="https:/...|               |24,978,452 in Clo...|            |                    |     |bo'em Women's Ula...|11.4 x 5.3 x 4.3 ...|             null|                  null|             null|           null|     null|[100% Leather, Le...|               null|      July 2, 2008|             null|                    null|
# |                  []|                  []|B0016N0SP2|                    |[Clothing, Shoes ...|<div class="a-fix...|[RAMPAGE caters t...|                    |[https://images-n...|<img src="https:/...|               |23,668,894 in Clo...|            |                    |     |Rampage Women's C...|10.9 x 5.8 x 4.3 ...|             null|                  null|             null|           null|     null|[100% Synthetic, ...|               null|    April 25, 2008|             null|                    null|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+
# only showing top 50 rows

# %% [markdown]
# **Now we will proceed on the following columns:**
# - 'image', we will create a column with the number of url images that each array contains.
# - 'price' we will eliminate the dollar sign '$' and we will create 2 new columns, one for the minimum price and another for the maximum price, in the minimum price we will have the quantity on the left and the quantity on the maximum right side as long as it exists Otherwise, the value of the left quantity will be taken. In case the column value is empty, the value of the two new columns will be null.

# %%
from pyspark.sql.types import IntegerType

# Function that returns the length of a list
def longitud_lista(lista):
    return len(lista)

# Create the udf longitud_udf 
longitud_udf = udf(longitud_lista, IntegerType())

# Create a new column and add the value that is the length of the list that we have calculated
df2 = df2.withColumn('num_image', longitud_udf(df2.image))

# Replace $ in the 'price' column with ""
df2 = df2.withColumn('price', regexp_replace('price', '\\$', ''))

# Split 'price' column into two parts using ' - ' separator
split_col = split(df2['price'], ' - ')

# Create the 'minimum_price' column with the first value of the split column
df2 = df2.withColumn('min_price', when(df2['price'].isNull(), None).otherwise(round(split_col.getItem(0).cast('float'),2)))

# Create column 'max_price' with second column value split if it exists, or add first column value
df2 = df2.withColumn('max_price', when(df2['price'].isNull(), None).otherwise(when(split_col.getItem(1).isNull(), round(split_col.getItem(0).cast('float'),2)).otherwise(round(split_col.getItem(1).cast('float'),2))))

# Drop column 'price' and 'image'
df2 = df2.drop('price','image')

# %%
df2.show(50)
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+---------+---------+---------+
# |            also_buy|           also_view|      asin|               brand|            category|                date|         description|                 fit|            main_cat|                rank|similar_item|               tech1|tech2|               title|  product_dimensions|domestic_shipping|international_shipping|item_model_number|shipping_weight|batteries|         new_feature|domestic_shipping_2|          new_date|shipping_weight_2|international_shipping_2|num_image|min_price|max_price|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+---------+---------+---------+
# |                  []|                  []|B0016MJOQM|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|[Great looking 10...|                    |<img src="https:/...|24,469,411 in Clo...|            |                    |     |Got Orr Little Bo...|                null|             null|                  null|             null|           null|     null|[100% Cotton, Mac...|               null|    April 14, 2015|             null|                    null|        2|    11.94|    11.94|
# |                  []|[B00SFZYXAK, B001...|B0016MJWDW|         RG Costumes|[Clothing, Shoes ...|                    |[Includes: Jumpsu...|                    |        Toys & Games|[">#720,785 in To...|            |                    |     |Grey Cute-T Bat K...|                null|             null|                  null|             null|           null|     null|           [90079-S]|               null|              null|             null|                    null|        0|    27.25|    27.25|
# |                  []|                  []|B0016MJQO2|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|[Great looking 10...
               bo'em|[Clothing, Shoes ...|<div class="a-fix...|[The bo'em collec...|                    |<img src="https:/...|24,978,452 in Clo...|            |                    |     |bo'em Women's Ula...|11.4 x 5.3 x 4.3 ...|             null|                  null|             null|           null|     null|[100% Leather, Le...|               null|      July 2, 2008|             null|                    null|        6|     null|     null|
# |                  []|                  []|B0016N0SP2|                    |[Clothing, Shoes ...|<div class="a-fix...|[RAMPAGE caters t...|                    |<img src="https:/...|23,668,894 in Clo...|            |                    |     |Rampage Women's C...|10.9 x 5.8 x 4.3 ...|             null|                  null|             null|           null|     null|[100% Synthetic, ...|               null|    April 25, 2008|             null|                    null|        6|     null|     null|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+---------+---------+---------+
# only showing top 50 rows

# %% [markdown]
# - 'main_cat', we observe that in this column there is a plain text which is a url of an image that has the title 'AMAZON FASHION', we will create a new column and add all the values that are different from the url of the column 'main_cat' and as for the values of the url we will take the title that appears after 'alt=' and add it to the values of the new column in their places respectively.
# - 'description', this column contains the description of the product within an array respectively, what we will do is extract the text and add it to a new column

# %%
# Extract the phrase after the 'alt=' attribute using a regular expression
alt_text = regexp_extract(df2['main_cat'], 'alt="([^"]+)"', 1)

# Create a new column with the values of the 'main' column, but replacing the records in the format '<img src="..." alt="..."/>' with the phrase after the 'alt= attribute ' and applying initcap
df2 = df2.withColumn('new_main_cat', when(alt_text != '', initcap(alt_text)).otherwise(df2['main_cat']))

# Creates a new column called "new_description" in the df2 DataFrame, which contains the values of the column "description" converted to strings
df2 = df2.withColumn("new_description", concat_ws(", ", col("description")))

# Drop column 'price' and 'image'
df2 = df2.drop('description','main_cat')

# %%
df2.show(50)
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+---------+---------+---------+--------------------+--------------------+
# |            also_buy|           also_view|      asin|               brand|            category|                date|                 fit|                rank|similar_item|               tech1|tech2|               title|  product_dimensions|domestic_shipping|international_shipping|item_model_number|shipping_weight|batteries|         new_feature|domestic_shipping_2|          new_date|shipping_weight_2|international_shipping_2|num_image|min_price|max_price|        new_main_cat|     new_description|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+---------+---------+---------+--------------------+--------------------+
# |                  []|                  []|B0016MJOQM|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...|                    |24,469,411 in Clo...|            |                    |     |Got Orr Little Bo...|                null|             null|                  null|             null|           null|     null|[100% Cotton, Mac...|               null|    April 14, 2015|             null|                    null|        2|    11.94|    11.94|      Amazon Fashion|Great looking 100...|
# |                  []|[B00SFZYXAK, B001...|B0016MJWDW|         RG Costumes|[Clothing, Shoes ...|                    |                    |[">#720,785 in To...|            |                    |     |Grey Cute-T Bat K...|                null|             null|                  null|             null|           null|     null|           [90079-S]|               null|              null|             null|                    null|        0|    27.25|    27.25|        Toys & Games|Includes: Jumpsui...|
# |                  []|                  []|B0016MJQO2|            99 Volts|[Clothing, Shoes ...|<div class="a-fix...
 2008|             null|                    null|        6|     null|     null|      Amazon Fashion|The bo'em collect...|
# |                  []|                  []|B0016N0SP2|                    |[Clothing, Shoes ...|<div class="a-fix...|                    |23,668,894 in Clo...|            |                    |     |Rampage Women's C...|10.9 x 5.8 x 4.3 ...|             null|                  null|             null|           null|     null|[100% Synthetic, ...|               null|    April 25, 2008|             null|                    null|        6|     null|     null|      Amazon Fashion|RAMPAGE caters to...|
# +--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+--------------------+------------+--------------------+-----+--------------------+--------------------+-----------------+----------------------+-----------------+---------------+---------+--------------------+-------------------+------------------+-----------------+------------------------+---------+---------+---------+--------------------+--------------------+
# only showing top 50 rows

# %% [markdown]
# # **ETL FOR THE DATASET METADATA**
#
# - **Extraction of the metadata dataset that is in the datalake in the Azure cloud**
# - **Transformation, cleaning and normalization of each part of the downloaded dataset**
# - **Loading each part of the dataset to the Google BigQuery cloud**

# %%
import datetime
from google.cloud import bigquery
import pandas
import pytz
from google.oauth2 import service_account
from google.cloud import storage
from pyspark.sql.functions import * 
from pyspark.sql.types import IntegerType, ArrayType, StringType, MapType, StructType, StructField
import re

metadata_directory = 'wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_metadata'
metadata_files = dbutils.fs.ls(metadata_directory)

# Function that returns the values of the feature column
def extraer_valores(lista):
    valores = {
        "fecha": None,
        "package_dimensions": None,
        "shipping_weight": None,
        "domestic_shipping": None,
        "international_shipping": None
    }
    nueva_lista = []
    for elemento in lista:
        elemento = elemento.replace("\n", "")
        lista_texto = elemento.split()
        elemento = " ".join(lista_texto)

        match = re.search(r"Date first listed on Amazon: </span> <span>([^<]+)", elemento)
        if match:
            valores["date"] = match.group(1)
        
        match = re.search(r"Package Dimensions: </span> <span>([^<]+)", elemento)
        if match:
            valores["package_dimensions"] = match.group(1)
        
        match = re.search(r"Shipping Weight: </span> <span>([^<]+)", elemento)
        if match:
            valores["shipping_weight_2"] = match.group(1)
        
        match = re.search(r"Domestic Shipping: </span> <span>([^<]+)", elemento)
        if match:
            valores["domestic_shipping_2"] = match.group(1)
        
        match = re.search(r"International Shipping: </span> <span>([^<]+)", elemento)
        if match:
            valores["international_shipping_2"] = match.group(1)
    
        if not re.search(r"span class", elemento):
            nueva_lista.append(elemento)

    return (valores, nueva_lista)

# Function that returns the length of a list
def longitud_lista(lista):
    return len(lista)

# Create the udf longitud_udf
longitud_udf = udf(longitud_lista, IntegerType())

# Funtion return key
def get_value(details, key):
    try:
        return details[key]
    except:
        return None

for file_info in metadata_files:
    
    df_meta=spark.read.option("header",True).json(file_info.path[:-1]) 

    # Create a new column and add the value that is the length of the list that we have calculated
    df_meta = df_meta.withColumn('num_image', longitud_udf(df_meta.image))

    # Replace $ in the price column with ""
    df_meta = df_meta.withColumn('price', regexp_replace('price', '\\$', ''))

    # Split 'price' column into two parts using ' - ' separator
    split_col = split(df_meta['price'], ' - ')

    # Create the 'minimum_price' column with the first value of the split column
    df_meta = df_meta.withColumn('min_price', when(df_meta['price'].isNull(), None).otherwise(round(split_col.getItem(0).cast('float'),2)))

    # Create the 'max_price' column with the second column value split if it exists, or add the first column value
    df_meta = df_meta.withColumn('max_price', when(df_meta['price'].isNull(), None).otherwise(when(split_col.getItem(1).isNull(), round(split_col.getItem(0).cast('float'),2)).otherwise(round(split_col.getItem(1).cast('float'),2))))

    # Extract the phrase after the 'alt=' attribute using a regular expression
    alt_text = regexp_extract(df_meta['main_cat'], 'alt="([^"]+)"', 1)

    # Create a new column with the values of the 'main' column, but replacing the records in the format '<img src="..." alt="..."/>' with the phrase after the 'alt= attribute ' and applying initcap
    df_meta = df_meta.withColumn('new_main_cat', when(alt_text != '', initcap(alt_text)).otherwise(df_meta['main_cat']))

    # creates a new column called "new description" in the df2 DataFrame, which contains the values of the "description" column converted to strings
    df_meta = df_meta.withColumn("new_description", concat_ws(", ", col("description")))

    # Removal of unnecessary columns
    df_meta = df_meta.drop('image', 'price', 'description','main_cat')

    # We create new columns with the values and keys of the details column

    udf_batteries = udf(get_value, StringType())

    # Extract the values from the details column
    try:
        df_meta = df_meta.withColumn("item_weight", get_value(df_meta.details, "\n    Item Weight: \n    "))
    except:
        pass
    
    try:
        df_meta = df_meta.withColumn("product_dimensions", get_value(df_meta.details, "\n    Product Dimensions: \n    "))
    except:
        pass

    try:
        df_meta = df_meta.withColumn("domestic_shipping", get_value(df_meta.details, "Domestic Shipping: "))
    except:
        pass

    try:
        df_meta = df_meta.withColumn("international_shipping", get_value(df_meta.details, "International Shipping: "))
    except:
        pass

    try:
        df_meta = df_meta.withColumn("item_model_number", get_value(df_meta.details, "Item model number:"))
    except:
        pass

    try:
        df_meta = df_meta.withColumn("shipping_weight", get_value(df_meta.details, "Shipping Weight:"))
    except:
        pass

    try:
        df_meta = df_meta.withColumn("batteries", get_value(df_meta.details, "Batteries"))
    except:
        pass

    # Defines the output schema of the udf
    schema = StructType([
        StructField("value_temp", MapType(StringType(), StringType())),
        StructField("new_feature", ArrayType(StringType()))
    ])

    # Treate the udf
    extraer_valores_udf = udf(extraer_valores, schema)

    # Applies the udf to the desired column and stores the results in two new columns
    df_meta = df_meta.withColumn("resultado", extraer_valores_udf("feature"))
    df_meta = df_meta.select("*", "resultado.value_temp", "resultado.new_feature")

    # We create new columns with the values and keys of the value_temp column
    df_meta = df_meta.withColumn("domestic_shipping_2", col('value_temp').getItem('domestic_shipping')) \
            .withColumn("product_dimensions", col("value_temp").getItem("package_dimensions")) \
            .withColumn("new_date", col('value_temp').getItem('date')) \
            .withColumn("shipping_weight_2", col("value_temp").getItem("shipping_weight").cast("string")) \
            .withColumn("domestic_shipping_2", col('value_temp').getItem('domestic_shipping').cast("string")) \
            .withColumn("international_shipping_2", col("value_temp").getItem("international_shipping").cast("string")) \
                
    df_meta = df_meta.drop('details', 'resultado', 'value_temp', 'feature')

    # Convert the DataFrame from Spark to a DataFrame in Pandas
    df_pandas = df_meta.toPandas()

    key_path= "/Workspace/Users/alfredoargumedointcol@gmail.com/clave.json"
    project_id="azuredatathonic26723"
    dataset_id = "ml_data"
    table="metadata_completa"
        
    table_id="{}.{}.{}".format(project_id, dataset_id, table)
    # print("********* NAME OF TABLE IS", table_id)
    credentials = service_account.Credentials.from_service_account_file(
        key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
        )

    # Construct a BigQuery client object.
    client = bigquery.Client(credentials=credentials, project=project_id)

    job_config = bigquery.LoadJobConfig(
        write_disposition="WRITE_APPEND")

    job = client.load_table_from_dataframe(
        df_pandas, table_id, job_config=job_config
    )  
    job.result()  

    data = client.get_table(table_id)
# Out:
# /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.9/site-packages/google/cloud/bigquery/_pandas_helpers.py:603: UserWarning: Pyarrow could not determine the type of columns: domestic_shipping_2, shipping_weight_2, international_shipping_2.
#   warnings.warn(

# %% [markdown]
# # EDA
# > ## Reviews Files

# %%
# List the contents of the 'amazon_reviews' directory in the Azure Blob Storage container.
dbutils.fs.ls('wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews')
# Out:
# Out[5]: [FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1/', name='partition_1/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_10/', name='partition_10/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_100/', name='partition_100/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1000/', name='partition_1000/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1001/', name='partition_1001/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1002/', name='partition_1002/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1003/', name='partition_1003/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1004/', name='partition_1004/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1005/', name='partition_1005/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1006/', name='partition_1006/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1007/', name='partition_1007/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1008/', name='partition_1008/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1009/', name='partition_1009/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_101/', name='partition_101/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1010/', name='partition_1010/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1011/', name='partition_1011/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1012/', name='partition_1012/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1013/', name='partition_1013/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1014/', name='partition_1014/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1015/', name='partition_1015/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1016/', name='partition_1016/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1017/', name='partition_1017/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1018/', name='partition_1018/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1019/', name='partition_1019/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_102/', name='partition_102/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1020/', name='partition_1020/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1021/', name='partition_1021/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1022/', name='partition_1022/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1023/', name='partition_1023/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1024/', name='partition_1024/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1025/', name='partition_1025/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1026/', name='partition_1026/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1027/', name='partition_1027/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1028/', name='partition_1028/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1029/', name='partition_1029/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_103/', name='partition_103/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1030/', name='partition_1030/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1031/', name='partition_1031/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1032/', name='partition_1032/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1033/', name='partition_1033/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1034/', name='partition_1034/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1035/', name='partition_1035/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1036/', name='partition_1036/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1037/', name='partition_1037/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1038/', name='partition_1038/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1039/', name='partition_1039/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_104/', name='partition_104/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1040/', name='partition_1040/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1041/', name='partition_1041/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1042/', name='partition_1042/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1043/', name='partition_1043/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1044/', name='partition_1044/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1045/', name='partition_1045/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1046/', name='partition_1046/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1047/', name='partition_1047/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1048/', name='partition_1048/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1049/', name='partition_1049/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_105/', name='partition_105/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1050/', name='partition_1050/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1051/', name='partition_1051/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1052/', name='partition_1052/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1053/', name='partition_1053/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1054/', name='partition_1054/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1055/', name='partition_1055/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1056/', name='partition_1056/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1057/', name='partition_1057/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1058/', name='partition_1058/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1059/', name='partition_1059/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_106/', name='partition_106/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1060/', name='partition_1060/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1061/', name='partition_1061/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1062/', name='partition_1062/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1063/', name='partition_1063/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1064/', name='partition_1064/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1065/', name='partition_1065/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1066/', name='partition_1066/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1067/', name='partition_1067/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1068/', name='partition_1068/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1069/', name='partition_1069/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_107/', name='partition_107/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1070/', name='partition_1070/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1071/', name='partition_1071/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1072/', name='partition_1072/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1073/', name='partition_1073/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1074/', name='partition_1074/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1075/', name='partition_1075/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1076/', name='partition_1076/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1077/', name='partition_1077/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1078/', name='partition_1078/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1079/', name='partition_1079/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_108/', name='partition_108/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1080/', name='partition_1080/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1081/', name='partition_1081/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1082/', name='partition_1082/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1083/', name='partition_1083/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1084/', name='partition_1084/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1085/', name='partition_1085/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1086/', name='partition_1086/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1087/', name='partition_1087/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1088/', name='partition_1088/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1089/', name='partition_1089/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_109/', name='partition_109/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1090/', name='partition_1090/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1091/', name='partition_1091/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1092/', name='partition_1092/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1093/', name='partition_1093/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1094/', name='partition_1094/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1095/', name='partition_1095/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1096/', name='partition_1096/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1097/', name='partition_1097/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1098/', name='partition_1098/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1099/', name='partition_1099/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_11/', name='partition_11/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_110/', name='partition_110/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1100/', name='partition_1100/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1101/', name='partition_1101/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1102/', name='partition_1102/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1103/', name='partition_1103/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1104/', name='partition_1104/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1105/', name='partition_1105/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1106/', name='partition_1106/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1107/', name='partition_1107/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1108/', name='partition_1108/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1109/', name='partition_1109/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_111/', name='partition_111/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1110/', name='partition_1110/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1111/', name='partition_1111/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1112/', name='partition_1112/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1113/', name='partition_1113/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1114/', name='partition_1114/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1115/', name='partition_1115/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1116/', name='partition_1116/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1117/', name='partition_1117/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1118/', name='partition_1118/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1119/', name='partition_1119/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_112/', name='partition_112/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1120/', name='partition_1120/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1121/', name='partition_1121/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1122/', name='partition_1122/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1123/', name='partition_1123/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1124/', name='partition_1124/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1125/', name='partition_1125/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1126/', name='partition_1126/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1127/', name='partition_1127/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1128/', name='partition_1128/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1129/', name='partition_1129/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_113/', name='partition_113/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1130/', name='partition_1130/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1131/', name='partition_1131/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1132/', name='partition_1132/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1133/', name='partition_1133/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1134/', name='partition_1134/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_113
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# indows.net/amazon_reviews/partition_1761/', name='partition_1761/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1762/', name='partition_1762/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1763/', name='partition_1763/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1764/', name='partition_1764/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1765/', name='partition_1765/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1766/', name='partition_1766/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1767/', name='partition_1767/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1768/', name='partition_1768/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1769/', name='partition_1769/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_177/', name='partition_177/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1770/', name='partition_1770/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1771/', name='partition_1771/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1772/', name='partition_1772/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1773/', name='partition_1773/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1774/', name='partition_1774/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1775/', name='partition_1775/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1776/', name='partition_1776/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1777/', name='partition_1777/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1778/', name='partition_1778/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1779/', name='partition_1779/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_178/', name='partition_178/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1780/', name='partition_1780/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1781/', name='partition_1781/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1782/', name='partition_1782/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1783/', name='partition_1783/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1784/', name='partition_1784/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1785/', name='partition_1785/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1786/', name='partition_1786/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1787/', name='partition_1787/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1788/', name='partition_1788/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1789/', name='partition_1789/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_179/', name='partition_179/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1790/', name='partition_1790/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1791/', name='partition_1791/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1792/', name='partition_1792/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1793/', name='partition_1793/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1794/', name='partition_1794/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1795/', name='partition_1795/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1796/', name='partition_1796/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1797/', name='partition_1797/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1798/', name='partition_1798/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1799/', name='partition_1799/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_18/', name='partition_18/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_180/', name='partition_180/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1800/', name='partition_1800/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1801/', name='partition_1801/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1802/', name='partition_1802/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1803/', name='partition_1803/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1804/', name='partition_1804/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1805/', name='partition_1805/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1806/', name='partition_1806/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1807/', name='partition_1807/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1808/', name='partition_1808/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1809/', name='partition_1809/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_181/', name='partition_181/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1810/', name='partition_1810/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1811/', name='partition_1811/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1812/', name='partition_1812/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1813/', name='partition_1813/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1814/', name='partition_1814/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1815/', name='partition_1815/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1816/', name='partition_1816/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1817/', name='partition_1817/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1818/', name='partition_1818/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1819/', name='partition_1819/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_182/', name='partition_182/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1820/', name='partition_1820/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1821/', name='partition_1821/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1822/', name='partition_1822/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1823/', name='partition_1823/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1824/', name='partition_1824/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1825/', name='partition_1825/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1826/', name='partition_1826/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1827/', name='partition_1827/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1828/', name='partition_1828/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1829/', name='partition_1829/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_183/', name='partition_183/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1830/', name='partition_1830/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1831/', name='partition_1831/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1832/', name='partition_1832/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1833/', name='partition_1833/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1834/', name='partition_1834/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1835/', name='partition_1835/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1836/', name='partition_1836/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1837/', name='partition_1837/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1838/', name='partition_1838/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1839/', name='partition_1839/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_184/', name='partition_184/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1840/', name='partition_1840/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1841/', name='partition_1841/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1842/', name='partition_1842/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1843/', name='partition_1843/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1844/', name='partition_1844/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1845/', name='partition_1845/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1846/', name='partition_1846/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1847/', name='partition_1847/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1848/', name='partition_1848/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1849/', name='partition_1849/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_185/', name='partition_185/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1850/', name='partition_1850/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1851/', name='partition_1851/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1852/', name='partition_1852/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1853/', name='partition_1853/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1854/', name='partition_1854/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1855/', name='partition_1855/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1856/', name='partition_1856/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1857/', name='partition_1857/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1858/', name='partition_1858/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1859/', name='partition_1859/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_186/', name='partition_186/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1860/', name='partition_1860/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1861/', name='partition_1861/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1862/', name='partition_1862/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1863/', name='partition_1863/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1864/', name='partition_1864/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1865/', name='partition_1865/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1866/', name='partition_1866/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1867/', name='partition_1867/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1868/', name='partition_1868/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1869/', name='partition_1869/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_187/', name='partition_187/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1870/', name='partition_1870/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1871/', name='partition_1871/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1872/', name='partition_1872/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1873/', name='partition_1873/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1874/', name='partition_1874/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1875/', name='partition_1875/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1876/', name='partition_1876/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1877/', name='partition_1877/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1878/', name='partition_1878/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1879/', name='partition_1879/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_188/', name='partition_188/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1880/', name='partition_1880/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1881/', name='partition_1881/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1882/', name='partition_1882/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1883/', name='partition_1883/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1884/', name='partition_1884/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1885/', name='partition_1885/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1886/', name='partition_1886/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1887/', name='partition_1887/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1888/', name='partition_1888/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1889/', name='partition_1889/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_189/', name='partition_189/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1890/', name='partition_1890/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1891/', name='partition_1891/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1892/', name='partition_1892/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1893/', name='partition_1893/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1894/', name='partition_1894/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1895/', name='partition_1895/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1896/', name='partition_1896/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1897/', name='partition_1897/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1898/', name='partition_1898/', size=0, modificationTime=0),
#  FileInfo(path='wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1899/', name='partition_1899/', size=0, modificationTime=0),
#  ...]

# %%
# Read JSON data from the 'amazon_reviews/partition_1' directory and load it into a Spark DataFrame.
df_rev=spark.read.option("header",True).json('wasbs://source-files@safactoreddatathon.blob.core.windows.net/amazon_reviews/partition_1')
